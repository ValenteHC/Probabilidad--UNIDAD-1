# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenteHC/Probabilidad--UNIDAD-1/blob/main/Practica_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBABILIDAD Y ESTADISTICA
#
# ##UNIDAD 1
#
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
#
# #### Alumno: HERRERA CARRERA VALENTIN
#
# ##### **PROGRAMA 2: MAXIMO, MINIMO Y DISPERCION DE DATOS**

# %%
import random
import matplotlib.pyplot as plt
from statistics import *

# %%
Fabrica1 = []
for _ in range(100):
  numero_aleatorio = round(random.uniform(50,1000),2)
  Fabrica1.append(numero_aleatorio)

print(Fabrica1)
# Out:
# [550.69, 324.85, 345.46, 262.75, 423.76, 86.37, 260.58, 911.25, 739.27, 58.36, 139.67, 228.27, 671.38, 823.38, 381.71, 538.99, 724.31, 451.63, 954.96, 755.14, 79.27, 848.44, 285.18, 485.5, 134.72, 90.81, 340.97, 237.97, 709.85, 392.22, 770.51, 534.79, 200.21, 947.46, 409.01, 134.47, 904.64, 548.84, 537.14, 51.47, 787.47, 135.41, 673.92, 256.4, 414.4, 255.9, 781.93, 644.74, 991.24, 857.99, 637.29, 232.73, 949.42, 805.12, 105.35, 624.68, 182.54, 529.5, 698.47, 220.01, 780.08, 509.73, 459.29, 801.92, 875.15, 434.36, 148.07, 537.42, 231.19, 149.15, 909.5, 237.12, 693.55, 640.38, 69.91, 129.58, 388.79, 260.18, 714.68, 197.32, 150.65, 994.54, 362.94, 90.33, 503.33, 191.82, 948.75, 150.3, 753.92, 241.79, 449.05, 598.25, 113.83, 741.11, 705.93, 846.1, 130.17, 402.3, 778.98, 446.97]

# %%
Fabrica2 = []
for _ in range(100):
  numero_aleatorio = round(random.uniform(50,1000),2)
  Fabrica2.append(numero_aleatorio)

print(Fabrica2)
# Out:
# [771.64, 761.06, 112.02, 491.38, 934.84, 949.66, 601.96, 92.29, 502.2, 105.79, 157.89, 293.24, 669.27, 430.98, 722.9, 796.09, 924.15, 605.06, 351.22, 573.99, 787.04, 486.34, 964.64, 110.47, 797.34, 783.13, 637.07, 275.73, 780.64, 842.91, 882.18, 843.27, 567.83, 656.97, 440.38, 886.59, 345.57, 229.78, 401.77, 645.21, 259.3, 76.69, 600.85, 950.19, 339.6, 907.63, 52.3, 746.93, 841.2, 373.1, 989.86, 790.06, 667.93, 496.53, 569.49, 142.94, 621.98, 928.48, 807.19, 901.56, 943.42, 885.99, 545.26, 102.81, 655.17, 829.7, 768.23, 796.97, 153.94, 116.14, 217.09, 538.16, 205.59, 656.29, 378.93, 449.76, 666.6, 249.63, 710.68, 826.61, 535.85, 754.62, 120.28, 128.94, 131.84, 594.03, 485.37, 439.74, 207.1, 832.74, 81.66, 479.14, 225.09, 304.84, 775.36, 658.31, 135.89, 617.48, 173.79, 522.02]

# %% [markdown]
# MAXIMO, MINIMO, RANGO

# %%
maximo1 = max(Fabrica1)
minimo1 = min(Fabrica1)
rango1 = maximo1 - minimo1
media1 = mean(Fabrica1)
mediana1 = median(Fabrica1)
moda1 = mode(Fabrica1)
desviacion_estandar_Fabrica1 = stdev(Fabrica1)

print("Estadistica descriptiva de la Fabrica 1 \n","Media =",media1,
      "\n Medaiana =",mediana1,"\n Moda=",moda1, "\n Maximo=",maximo1,
      "\n Minimo =",minimo1,"\n Rango=", rango1)
print("Desviacion Estandar =", desviacion_estandar_Fabrica1)
# Out:
# Estadistica descriptiva de la Fabrica 1
#  Media = 478.2919
#  Medaiana = 450.34000000000003
#  Moda= 550.69
#  Maximo= 994.54
#  Minimo = 51.47
#  Rango= 943.0699999999999
# Desviacion Estandar = 281.78033158485476

# %%
maximo2 = max(Fabrica1)
minimo2 = min(Fabrica1)
rango2 = maximo1 - minimo1
media2 = mean(Fabrica1)
mediana2 = median(Fabrica1)
moda2 = mode(Fabrica1)
desviacion_estandar_Fabrica2 = stdev(Fabrica2)

print("Estadistica descriptiva de la Fabrica 2 \n","Media =",media2,
      "\n Medaiana =",mediana2,"\n Moda=",moda2, "\n Maximo=",maximo2,
      "\n Minimo =",minimo2,"\n Rango=", rango2)
print("Desviacion Estandar =", desviacion_estandar_Fabrica2)
# Out:
# Estadistica descriptiva de la Fabrica 2
#  Media = 478.2919
#  Medaiana = 450.34000000000003
#  Moda= 550.69
#  Maximo= 994.54
#  Minimo = 51.47
#  Rango= 943.0699999999999
# Desviacion Estandar = 278.4451531381019

# %%
plt.figure(figsize=(8,6))
plt.hist(Fabrica1,bins=10, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label=f'Media={media1:.2f}')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana1:.2f}')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda1:.2f}')
plt.axvline(media1 - desviacion_estandar_Fabrica1, color='black',linestyle='dashed', linewidth=2, label=f'Desviacion Estandar={desviacion_estandar_Fabrica1:.2f}')
plt.axvline(media1 + desviacion_estandar_Fabrica1, color='black',linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma de la Fabrica 1')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.hist(Fabrica2,bins=10, alpha=0.2,color='b', edgecolor='black')
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label=f'Media={media2:.2f}')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label=f'Mediana={mediana2:.2f}')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label=f'Moda={moda2:.2f}')
plt.axvline(media2 - desviacion_estandar_Fabrica2, color='black',linestyle='dashed', linewidth=2, label=f'Desviacion Estandar={desviacion_estandar_Fabrica2:.2f}')
plt.axvline(media2 + desviacion_estandar_Fabrica2, color='black',linestyle='dashed', linewidth=2)

plt.xlabel('Valor')
plt.ylabel('Frecuencia')
plt.title('Histograma de la Fabrica 2')
plt.legend()
plt.show()

# %%
import seaborn as sns

# La densidad grafica es una forma de viasualizar la distubucion de datos en un intervalo o periodo de tiempo continuo.
#Se basa en un histograma que usa el suavizado de kernel para trazar valores, lo que permite obtener distibuciones mas suaves al reducir el ruido.
#Una curva de densidad muestra la ubicacion de la media y la mediana de una distribucion .

sns.histplot( x = Fabrica1 , kde = True, kde_kws = {'bw_adjust': 0.5}, bins = 10 )
# Out:
# <Axes: ylabel='Count'>
