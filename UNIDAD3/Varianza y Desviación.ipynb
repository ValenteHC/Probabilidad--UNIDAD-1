# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenteHC/Probabilidad--UNIDAD-1/blob/main/UNIDAD3/Varianza%20y%20Desviaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBABILIDAD Y ESTADISTICA
#
# ##UNIDAD 3
#
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
#
# #### Alumno: HERRERA CARRERA VALENTIN
#
# ##### **PROGRAMA 3: Varianza y desviación estándar**

# %%
import math
x = [5,6,7,8,9,10]
p = [0.05,0.10,0.20,0.30,0.25,0.10]

#Calcular E(X)
esperanza = 0
for i in range (len(x)):
  esperanza += x[i]*p[i]

#Calcular E(X^2)
esperanza_cuadrado = 0
for i in range (len(x)):
  esperanza_cuadrado += (x[i]**2)*p[i]

#Calcular varianza y desviación estándar
varianza = esperanza_cuadrado - esperanza**2
desviacion = math.sqrt(varianza)

#Moatrar resultados
print(f"E(X)= {esperanza:.2f}")
print(f"E(X^2)= {esperanza_cuadrado:.2f}")
print(f"Varianza= {varianza:.2f}")
print(f"Desviación estándar= {desviacion:.2f}")
# Out:
# E(X)= 7.90
# E(X^2)= 64.10
# Varianza= 1.69
# Desviación estándar= 1.30
