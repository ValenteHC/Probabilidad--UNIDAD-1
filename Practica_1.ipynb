# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenteHC/Probabilidad-/blob/main/Practica_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBABILIDAD Y ESTADISTICA
#
# ##UNIDAD 1
#
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
#
# #### Alumno: HERRERA CARRERA VALENTIN
#
# ##### **PROGRAMA 1: ESTADISTICA e HISTOGRAMAS**

# %%
from statistics import*

# %%
# lista de calificaciones del grupo A de probabilidad y estadistica
grupoa = [70, 65, 90,100, 95, 45, 88, 73, 20, 100,96 ]
print(grupoa)
type(grupoa)
# Out:
# [70, 65, 90, 100, 95, 45, 88, 73, 20, 100, 96]
# list

# %%
# la funcion type nos devuelve el tipo de dato de la variable
type(grupoa)
# Out:
# list

# %%
# Sacar la medida de las calificaiones con una formula
promedio = sum(grupoa)/len(grupoa)

# %%
# Utilizar la funcion mean que esta en la libreria statics para sacar
# Promedio:
Promedio2 = mean(grupoa)
print(Promedio2)
# Out:
# 76.54545454545455

# %%
# Determinar el valor de la media con la funcion median

mediana = median(grupoa)
print(mediana)
# Out:
# 88

# %%
# Determinar el valor de la moda con la funcion mode
moda = mode(grupoa)
print(moda)
# Out:
# 100

# %%
# En caso de que exista mas de una moda, se puede emplear la funcion multimode para sacar
#Multiples modas que pueden existir

moda2 = multimode(grupoa)
print(moda2)
# Out:
# [100]

# %%
tiempos100mts = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
print(tiempos100mts)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("El tiempo promedio de los corredores es=> ", mean(tiempos100mts))
print("El tiempo promedio de los corredores es=> ", median(tiempos100mts))
print("El tiempo promedio de los corredores es=> ", mode(tiempos100mts))
# Out:
# El tiempo promedio de los corredores es=>  17.322
# El tiempo promedio de los corredores es=>  17.2
# El tiempo promedio de los corredores es=>  15.1

# %%
import random

# %%
import random

fabrica1 =[]
for i in range(100):
  numero_aleatorio = round(random.uniform(50,100),2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [90.72, 72.35, 89.52, 58.66, 83.31, 65.12, 57.36, 94.75, 96.03, 61.29, 57.24, 73.48, 83.36, 64.85, 93.54, 89.84, 98.28, 52.42, 68.82, 59.86, 80.68, 97.02, 88.75, 93.68, 72.26, 61.63, 74.92, 93.4, 64.72, 78.48, 84.03, 85.07, 50.03, 54.49, 52.8, 55.24, 97.4, 57.74, 85.8, 50.05, 80.2, 51.84, 82.3, 55.35, 61.06, 80.79, 52.32, 99.3, 98.31, 61.93, 66.67, 93.93, 71.0, 83.39, 94.04, 99.83, 75.66, 84.39, 70.05, 56.88, 80.34, 95.15, 57.42, 64.02, 99.09, 65.09, 62.11, 73.09, 88.83, 56.68, 92.31, 53.97, 94.32, 82.06, 80.04, 74.62, 55.51, 74.01, 53.71, 99.41, 94.8, 74.26, 90.4, 77.4, 79.29, 79.84, 76.12, 72.6, 79.82, 94.38, 78.97, 96.07, 99.46, 54.36, 91.43, 75.04, 86.56, 74.15, 98.26, 84.52]

# %%
fabrica2 =[]
for i in range(100):
    numero_aleatorio = round(random.uniform(70,100),2)
    fabrica2.append(numero_aleatorio)
print(fabrica2)
# Out:
# [91.82, 92.17, 79.51, 81.65, 88.62, 94.32, 88.57, 85.96, 74.76, 74.89, 95.72, 99.33, 82.66, 77.51, 92.73, 85.78, 94.46, 76.83, 70.82, 71.41, 81.68, 84.69, 76.95, 89.92, 84.46, 87.53, 92.68, 79.42, 94.86, 86.48, 76.1, 72.4, 92.57, 82.84, 99.35, 96.1, 90.37, 91.32, 88.79, 84.51, 72.64, 82.67, 70.98, 87.65, 96.97, 99.59, 82.56, 84.66, 84.48, 72.04, 90.81, 87.79, 71.18, 77.48, 82.16, 86.52, 81.31, 92.39, 83.55, 72.98, 95.85, 94.09, 92.25, 91.57, 81.95, 79.38, 91.38, 96.19, 78.61, 86.16, 77.04, 94.3, 70.38, 76.5, 97.83, 90.92, 87.14, 76.44, 75.05, 93.7, 84.27, 81.64, 83.58, 92.31, 77.56, 78.36, 87.94, 88.84, 91.03, 93.38, 71.22, 76.74, 72.43, 86.63, 85.04, 93.54, 78.17, 70.01, 77.51, 79.66]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la fabrica 2 ")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la fabrica 2 ')

# %%
media1 = mean(fabrica1)
mediana1 = mean(fabrica1)
moda1 = mode(fabrica1)

print("Valores de medias de la fabrica 1")
print("La media es=", media1)
print("La mediana es=", mediana1)
print("La moda es=", moda1)
# Out:
# Valores de medias de la fabrica 1
# La media es= 76.6774
# La mediana es= 76.6774
# La moda es= 90.72

# %%
media2 = mean(fabrica2)
mediana = mean(fabrica2)
moda = mode(fabrica2)

print("Valores de medias de la fabrica 2")
print("La media es=", media2)
print("La mediana es=", mediana)
print("La moda es=", moda)
# Out:
# Valores de medias de la fabrica 2
# La media es= 84.6954
# La mediana es= 84.6954
# La moda es= 77.51

# %%
fig, (ax1, ax2) = plt.subplots(nrows = 1,ncols = 2, figsize = (10,5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()
