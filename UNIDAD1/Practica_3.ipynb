# %% [markdown]
# <a href="https://colab.research.google.com/github/ValenteHC/Probabilidad--UNIDAD-1/blob/main/UNIDAD1/Practica_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # PROBABILIDAD Y ESTADISTICA
#
# ##UNIDAD 1
#
# ###FACILITADOR: Jose Gabriel Rodrigues Rivas
#
# #### Alumno: HERRERA CARRERA VALENTIN
#
# ##### **PROGRAMA 3: TABLAS DE FRECUENCIA**

# %%
#Basado en el LIBRO estadistica para administracion pagina 12
#creamos una lista vacia que que representa la edad de 100 personas
import random
edades = []
#Hacemos un ciclo para generar 100 numeros aleatorias que representan la edad de las personas
for i in range(100):
  #generamos un numero aleatorio con la funcion ranint y lo guardamos en la variable
  #numero aleatorio
  numero_aleatrio = random.randint(18,65)
  #Agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatrio)
print(edades)
# Out:
# [65, 51, 60, 61, 30, 19, 36, 64, 41, 56, 41, 27, 36, 30, 51, 38, 43, 57, 40, 33, 19, 25, 33, 42, 35, 58, 23, 23, 49, 34, 27, 23, 18, 58, 37, 42, 19, 21, 53, 21, 44, 52, 26, 50, 62, 41, 54, 19, 45, 31, 50, 50, 59, 64, 19, 18, 32, 62, 38, 32, 57, 58, 53, 45, 36, 36, 33, 34, 54, 49, 23, 61, 55, 50, 64, 60, 59, 48, 19, 21, 33, 28, 29, 19, 20, 28, 24, 23, 56, 43, 53, 60, 42, 43, 44, 26, 38, 50, 64, 53]

# %%
import pandas as pd

# %%
#Crear un DataFrame de pandas con los numeros aleatorios
df = pd.DataFrame(edades, columns = ['Edades'])
df.head()
# Out:
#    Edades
# 0      65
# 1      51
# 2      60
# 3      61
# 4      30

# %%
#Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['Edades'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edades','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edades')

#Imprimir la tabla de distribucion de frecuencias
print("Tabla de Distribucion de Frecuencias: ")
tabla_frecuencias
# Out:
# Tabla de Distribucion de Frecuencias:
#     Edades  Frecuencia
# 21      18           2
# 0       19           7
# 41      20           1
# 9       21           3
# 2       23           5
# 42      24           1
# 33      25           1
# 24      26           2
# 14      27           2
# 19      28           2
# 40      29           1
# 17      30           2
# 37      31           1
# 29      32           2
# 3       33           4
# 20      34           2
# 34      35           1
# 5       36           4
# 35      37           1
# 12      38           3
# 32      40           1
# 8       41           3
# 13      42           3
# 11      43           3
# 25      44           2
# 27      45           2
# 39      48           1
# 22      49           2
# 1       50           5
# 15      51           2
# 36      52           1
# 4       53           4
# 28      54           2
# 38      55           1
# 18      56           2
# 26      57           2
# 10      58           3
# 30      59           2
# 7       60           3
# 16      61           2
# 23      62           2
# 6       64           4
# 31      65           1

# %%
tabla_frecuencias["Frac Relativa"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frac Relativa
# 21      18           2           0.02
# 0       19           7           0.07
# 41      20           1           0.01
# 9       21           3           0.03
# 2       23           5           0.05
# 42      24           1           0.01
# 33      25           1           0.01
# 24      26           2           0.02
# 14      27           2           0.02
# 19      28           2           0.02
# 40      29           1           0.01
# 17      30           2           0.02
# 37      31           1           0.01
# 29      32           2           0.02
# 3       33           4           0.04
# 20      34           2           0.02
# 34      35           1           0.01
# 5       36           4           0.04
# 35      37           1           0.01
# 12      38           3           0.03
# 32      40           1           0.01
# 8       41           3           0.03
# 13      42           3           0.03
# 11      43           3           0.03
# 25      44           2           0.02
# 27      45           2           0.02
# 39      48           1           0.01
# 22      49           2           0.02
# 1       50           5           0.05
# 15      51           2           0.02
# 36      52           1           0.01
# 4       53           4           0.04
# 28      54           2           0.02
# 38      55           1           0.01
# 18      56           2           0.02
# 26      57           2           0.02
# 10      58           3           0.03
# 30      59           2           0.02
# 7       60           3           0.03
# 16      61           2           0.02
# 23      62           2           0.02
# 6       64           4           0.04
# 31      65           1           0.01

# %%
tabla_frecuencias["Frac Porcentaje"] = tabla_frecuencias["Frecuencia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frac Relativa  Frac Porcentaje
# 21      18           2           0.02              2.0
# 0       19           7           0.07              7.0
# 41      20           1           0.01              1.0
# 9       21           3           0.03              3.0
# 2       23           5           0.05              5.0
# 42      24           1           0.01              1.0
# 33      25           1           0.01              1.0
# 24      26           2           0.02              2.0
# 14      27           2           0.02              2.0
# 19      28           2           0.02              2.0
# 40      29           1           0.01              1.0
# 17      30           2           0.02              2.0
# 37      31           1           0.01              1.0
# 29      32           2           0.02              2.0
# 3       33           4           0.04              4.0
# 20      34           2           0.02              2.0
# 34      35           1           0.01              1.0
# 5       36           4           0.04              4.0
# 35      37           1           0.01              1.0
# 12      38           3           0.03              3.0
# 32      40           1           0.01              1.0
# 8       41           3           0.03              3.0
# 13      42           3           0.03              3.0
# 11      43           3           0.03              3.0
# 25      44           2           0.02              2.0
# 27      45           2           0.02              2.0
# 39      48           1           0.01              1.0
# 22      49           2           0.02              2.0
# 1       50           5           0.05              5.0
# 15      51           2           0.02              2.0
# 36      52           1           0.01              1.0
# 4       53           4           0.04              4.0
# 28      54           2           0.02              2.0
# 38      55           1           0.01              1.0
# 18      56           2           0.02              2.0
# 26      57           2           0.02              2.0
# 10      58           3           0.03              3.0
# 30      59           2           0.02              2.0
# 7       60           3           0.03              3.0
# 16      61           2           0.02              2.0
# 23      62           2           0.02              2.0
# 6       64           4           0.04              4.0
# 31      65           1           0.01              1.0

# %%
tabla_frecuencias["Frac Acomulada"] = tabla_frecuencias["Frecuencia"].cumsum()
tabla_frecuencias
# Out:
#     Edades  Frecuencia  Frac Relativa  Frac Porcentaje  Frac Acomulada
# 21      18           2           0.02              2.0               2
# 0       19           7           0.07              7.0               9
# 41      20           1           0.01              1.0              10
# 9       21           3           0.03              3.0              13
# 2       23           5           0.05              5.0              18
# 42      24           1           0.01              1.0              19
# 33      25           1           0.01              1.0              20
# 24      26           2           0.02              2.0              22
# 14      27           2           0.02              2.0              24
# 19      28           2           0.02              2.0              26
# 40      29           1           0.01              1.0              27
# 17      30           2           0.02              2.0              29
# 37      31           1           0.01              1.0              30
# 29      32           2           0.02              2.0              32
# 3       33           4           0.04              4.0              36
# 20      34           2           0.02              2.0              38
# 34      35           1           0.01              1.0              39
# 5       36           4           0.04              4.0              43
# 35      37           1           0.01              1.0              44
# 12      38           3           0.03              3.0              47
# 32      40           1           0.01              1.0              48
# 8       41           3           0.03              3.0              51
# 13      42           3           0.03              3.0              54
# 11      43           3           0.03              3.0              57
# 25      44           2           0.02              2.0              59
# 27      45           2           0.02              2.0              61
# 39      48           1           0.01              1.0              62
# 22      49           2           0.02              2.0              64
# 1       50           5           0.05              5.0              69
# 15      51           2           0.02              2.0              71
# 36      52           1           0.01              1.0              72
# 4       53           4           0.04              4.0              76
# 28      54           2           0.02              2.0              78
# 38      55           1           0.01              1.0              79
# 18      56           2           0.02              2.0              81
# 26      57           2           0.02              2.0              83
# 10      58           3           0.03              3.0              86
# 30      59           2           0.02              2.0              88
# 7       60           3           0.03              3.0              91
# 16      61           2           0.02              2.0              93
# 23      62           2           0.02              2.0              95
# 6       64           4           0.04              4.0              99
# 31      65           1           0.01              1.0             100

# %%
#Importamos la libreria math de funcionnes matematicas
import math

# %%
#Volvemos a usar la lista de edades
print(edades)
# Out:
# [65, 51, 60, 61, 30, 19, 36, 64, 41, 56, 41, 27, 36, 30, 51, 38, 43, 57, 40, 33, 19, 25, 33, 42, 35, 58, 23, 23, 49, 34, 27, 23, 18, 58, 37, 42, 19, 21, 53, 21, 44, 52, 26, 50, 62, 41, 54, 19, 45, 31, 50, 50, 59, 64, 19, 18, 32, 62, 38, 32, 57, 58, 53, 45, 36, 36, 33, 34, 54, 49, 23, 61, 55, 50, 64, 60, 59, 48, 19, 21, 33, 28, 29, 19, 20, 28, 24, 23, 56, 43, 53, 60, 42, 43, 44, 26, 38, 50, 64, 53]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     65
# 1     51
# 2     60
# 3     61
# 4     30
# ..   ...
# 95    26
# 96    38
# 97    50
# 98    64
# 99    53
#
# [100 rows x 1 columns]

# %%
#Calcular el numero de intervalos utilizando la regla de Sturges
import math
n = len(edades)
K = int(1 + math.log2(n))
print("Valor de n= ", n , "\nNumero de intervalos=", K)
# Out:
# Valor de n=  100
# Numero de intervalos= 7

# %%
#Crear la tabla de frecuencia
tabla_frecuencia = pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#                           Clase  Frec
# 0  (17.951999999999998, 24.714]    19
# 1              (31.429, 38.143]    17
# 2              (51.571, 58.286]    15
# 3                (58.286, 65.0]    14
# 4              (44.857, 51.571]    12
# 5              (38.143, 44.857]    12
# 6              (24.714, 31.429]    11

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values (by='Clase')
tabla_frecuencia
# Out:
#                           Clase  Frec
# 0  (17.951999999999998, 24.714]    19
# 6              (24.714, 31.429]    11
# 1              (31.429, 38.143]    17
# 5              (38.143, 44.857]    12
# 4              (44.857, 51.571]    12
# 2              (51.571, 58.286]    15
# 3                (58.286, 65.0]    14

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] /n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# %%
#Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#                           Clase  Frec  Frec Rel  Frec Porc  Frec Ac  \
# 0  (17.951999999999998, 24.714]    19      0.19       19.0       19
# 6              (24.714, 31.429]    11      0.11       11.0       30
# 1              (31.429, 38.143]    17      0.17       17.0       47
# 5              (38.143, 44.857]    12      0.12       12.0       59
# 4              (44.857, 51.571]    12      0.12       12.0       71
# 2              (51.571, 58.286]    15      0.15       15.0       86
# 3                (58.286, 65.0]    14      0.14       14.0      100
#
#    Frec Rel Ac  Frec Porc Ac
# 0         0.19          19.0
# 6         0.30          30.0
# 1         0.47          47.0
# 5         0.59          59.0
# 4         0.71          71.0
# 2         0.86          86.0
# 3         1.00         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
